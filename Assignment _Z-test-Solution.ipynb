# %% [markdown]
# ## Assignment of Z-Test and T-Test
# ## MARMIK PARASHAR
# ## PRN 240810125002

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Defining a Function for Calculating the Z-Test Value
def Z_test(sample_mean,population_mean,population_std,sample_size,alpha,plt_title):
    # Step 2: Calculate Z-Test
    z_test = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Step 3: Determine critical Z-values for a two-tailed test at a 0.01 significance level
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Step 4: Compare Z-score with critical Z-value to make a decision
    reject_null = abs(z_test ) > z_critical

    # Step 5: Visualization
    # Standard normal distribution for visualization
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label="Standard Normal Distribution")
    plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color="red", alpha=0.3, label="Rejection Region")
    plt.axvline(z_test , color="blue", linestyle="--", label=f"Z-Test = {z_test :.2f}")
    plt.axvline(-z_critical, color="black", linestyle="--", label=f"Z-Critical = ±{z_critical:.2f}")
    plt.axvline(z_critical, color="black", linestyle="--")
    plt.xlabel("Z")
    plt.ylabel("Probability Density")
    plt.title(plt_title)
    plt.legend()
    plt.show()

    # Display results
    print("Z-Test:", z_test )
    print("Critical Z-Value:", z_critical)
    print("Reject Null Hypothesis:", reject_null)
    if(reject_null):
        print("There is sufficient evidence to reject the null hypothesis")
    else:
        print("There is insufficient evidence to reject the null hypothesis")

# %% [markdown]
# ## Q1- A university claims that its graduates earn an average starting salary of $60,000 per year.You take a sample of 100 graduates and find the average salary to be $58,000with a known population standard deviation of $10,000.Test the university's claim at a 0.05 significance level.

# %%
'''
Null Hypothesis (𝐻0): The average salary of graduates is $60,000 (𝜇=60,000).
Alternate Hypothesis (𝐻𝑎): The average salary of graduates is not $60,000 (𝜇≠60,000).

'''

# Given data for the Average Salary for Graduates
sample_mean = 58000
population_mean = 60000
population_std = 10000
sample_size = 100
alpha = 0.05

Z_test(58000,60000,10000,100,0.05,"Z-Test for Average Salary of Graduates")
# Out:
# Z-Test: -2.0
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q2. A hospital states that the average waiting time for patients is 20 minutes. A sample of 50 patients shows an average waiting time of 22 minutes with a population standard deviation of 5 minutes. Test the claim at a 0.01 significance level.

# %%
# Given data for the hospital waiting time problem
sample_mean = 22
population_mean = 20
population_std = 5
sample_size = 50
alpha = 0.01

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average waiting time is 20 minutes (mu = 20)
# Alternative Hypothesis (Ha): The average waiting time is not 20 minutes (mu ≠ 20)

Z_test(22,20,5,50,0.01,"Z-Test for Hospital Waiting Time Claim")
# Out:
# Z-Test: 2.8284271247461903
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q3. A company advertises that its batteries last an average of 40 hours. A sample of 75 batteries has an average life of 38 hours with a standard deviation of 6 hours. Is there sufficient evidence to reject the company’s claim at a 0.05 significance level?

# %%
# Given data for the Average Battery Life
sample_mean = 38
population_mean = 40
population_std = 6
sample_size = 75
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Battery Life is 40 hours (mu = 40)
# Alternative Hypothesis (Ha): The average Battery Life is not 40 hours (mu ≠ 40)

Z_test(38, 40, 6, 75, 0.05,"Z-Test for Average Battery Life")
# Out:
# Z-Test: -2.886751345948129
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# # Q4. A fast-food chain claims its average service time is 3.5 minutes. A sample of 120 customers shows a mean service time of 3.8 minutes with a standard deviation of 0.6 minutes. Test this claim at a 0.05 significance level.

# %%
'''
h0 - SERVICE TIME OF 3.5 MINUTES
HA - SERVICE TIME NOT 3.5 MINUTES
'''
# Given data for Fast-Food Service Time
Z_test(3.8,3.5,0.6,120,0.05,"Z-Test for the Average Service Time")
# Out:
# Z-Test: 5.4772255750516585
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q5. A car manufacturer states that the fuel efficiency of a specific model is 25 miles per gallon (mpg). A consumer report tests 40 cars and finds an average of 24 mpg with a known population standard deviation of 2.5 mpg. Test at a 0.05 significance level.

# %%
'''
H0 FUEL EFFICIENCY IS 20 MILES PER GALLON
HA - NOT 20M/G

'''

# Given data for Car Fuel Efficiency
Z_test(24,25,2.5,40,0.05,"Z-Test for Fuel Efficiency")
# Out:
# Z-Test: -2.5298221281347035
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q6. A school district claims that students score an average of 85 on a standardized math test. A sample of 30 students has an average score of 82, with a known population standard deviation of 8. Test the claim at a 0.05 significance level.

# %%
'''
H0 - AVERGAE OF STUDENTS 85
HA- AVG SCORE NOT 85
'''
# Given data for School District Test Score
Z_test(82,85,8,30,0.05,"Z-Test for the Student Score")
# Out:
# Z-Test: -2.0539595906443733
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q7. An airline asserts that its flights have an average delay time of 15 minutes. A sample of 60 flights shows an average delay of 17 minutes with a population standard deviation of 4 minutes. Test the claim at a 0.01 significance level.

# %%
'''
H0 - AVERAGE DELAY 15 MINUTES
HA- AVERAGE DELAY NOT 15 MINUTES
'''
# Given data for Airline Delay Time

Z_test(17,15,4,60,0.01,"Z-Test for Airline Delay Time")
# Out:
# Z-Test: 3.8729833462074175
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 11 A bank claims that the average processing time for a loan is 15 days. A sample of 35 loans shows an average processing time of 16 days with a population standard deviation of 3 days. Test at a 0.01 significance level.

# %%
# Given data for the Bank loan problem
sample_mean = 16
population_mean = 15
population_std = 3
sample_size = 35
alpha = 0.01

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Time for Bank to Process Loan is 15 Days (mu = 15)
# Alternative Hypothesis (Ha): The average Time for Bank to Process Loan is not 15 Days (mu ≠ 15)

Z_test(16,15,3,35,0.01,"Z-Test for Bank Loan Processing Time")
# Out:
# Z-Test: 1.9720265943665387
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: False
# There is insufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 12.A pharmaceutical company states its drug reduces blood pressure by an average of 10 mmHg. A study on 90 patients finds an average reduction of 9 mmHg with a standard deviation of 2 mmHg. Test the claim at a 0.05 significance level.

# %%
# Given data for the Pharmaceutical Company Drug for reducing Blood Pressure
sample_mean = 9
population_mean = 10
population_std = 2
sample_size = 90
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The Average Blood Pressure Reduced By Drug is 10 mmHg (mu = 10)
# Alternative Hypothesis (Ha): The Average Blood Pressure Reduced By Drug is not 10 mmHg (mu ≠ 10)

Z_test(9,10,2,90,0.05,"Z-Test for Pharmaceutical Company Drug for Reducing Blood Pressure")
# Out:
# Z-Test: -4.743416490252569
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 13. A high school claims its average graduation rate is 92%. A sample of 100 students shows a graduation rate of 90% with a standard deviation of 4%. Test the claim at a 0.05 significance level.

# %%
# Given data for Average Graduation Rate
sample_mean = 0.90
population_mean = 0.92
population_std = 0.04
sample_size = 90
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Graduation rate is 92%  (mu = 0.92)
# Alternative Hypothesis (Ha): The average Graduation rate is not 92%  (mu ≠ 0.92)

Z_test(0.90,0.92,0.04,90,0.05,"Z- Test for Average Graduation Rate")
# Out:
# Z-Test: -4.743416490252573
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 14. A coffee shop claims its average serving time is 4 minutes. A sample of 70 customers has an average serving time of 4.5 minutes with a population standard deviation of 1 minute. Test the claim at a 0.05 significance level.

# %%
# Given data for Average Serving Time for Coffe Shop
sample_mean = 0.90
population_mean = 0.92
population_std = 0.04
sample_size = 90
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Graduation rate is 92%  (mu = 0.92)
# Alternative Hypothesis (Ha): The average Graduation rate is not 92%  (mu ≠ 0.92)

Z_test(0.90,0.92,0.04,90,0.05,"Z- Test for Average Serving Time For Coffe Shop")
# Out:
# Z-Test: -4.743416490252573
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 15 A tech company advertises that its smartphone battery lasts an average of 24 hours. A sample of 40 phones shows an average battery life of 23 hours with a standard deviation of 3 hours. Test the claim at a 0.01 significance level.

# %%
# Given data for Average Serving Time for Coffe Shop
sample_mean = 23
population_mean = 24
population_std = 3
sample_size = 40
alpha = 0.01

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Smartphone Battery Life is 24 hours  (mu = 24)
# Alternative Hypothesis (Ha): The average Smartphone Battery Life is not 24 hours (mu ≠ 24)

Z_test(23,24,3,40,0.01,"Z- Test for Average Smartphone Battery Life")
# Out:
# Z-Test: -2.1081851067789197
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: False
# There is insufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 16. A retail store claims that the average customer spends $100 during each visit. A sample of 50 customers has an average spending of $95 with a standard deviation of $15. Test the claim at a 0.05 significance level.

# %%
# Given data for Average Customer Spending 
sample_mean = 95
population_mean = 100
population_std = 15
sample_size = 50
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Spend of customer is $100  (mu = 100)
# Alternative Hypothesis (Ha): The average Spend of customer is not $100 (mu ≠ 100)

Z_test(95,100,15,50,0.05,"Z- Test for Average Customer Spending")
# Out:
# Z-Test: -2.3570226039551585
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %% [markdown]
# ## Q 17. A sports club claims that the average time for a 5k run is 25 minutes. A sample of 60 runners has an average of 24 minutes with a population standard deviation of 3 minutes. Test at a 0.05 significance level.

# %%
# Given data for Average Time for Sports Club 5 Km Run 
sample_mean = 24
population_mean = 25
population_std = 3
sample_size = 60
alpha = 0.05

# Step 1: Define Hypotheses
# Null Hypothesis (H0): The average Spend of customer is $100  (mu = 100)
# Alternative Hypothesis (Ha): The average Spend of customer is not $100 (mu ≠ 100)

Z_test(sample_mean,population_mean,population_std,sample_size,alpha,"Z- Test for Average Customer Spending")
# Out:
# Z-Test: -2.581988897471611
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 18
Z_test(118, 120, 10, 80, 0.05, "Energy Company Monthly Bill")
# Out:
# Z-Test: -1.7888543819998317
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: False
# There is insufficient evidence to reject the null hypothesis

# %%
# Question 19
Z_test(9, 10, 1.5, 30, 0.01, "Cosmetic Brand Wrinkle Reduction")
# Out:
# Z-Test: -3.6514837167011076
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 20
Z_test(5.5, 5, 0.8, 100, 0.05, "Grocery Store Checkout Time")
# Out:
# Z-Test: 6.25
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 21
Z_test(1.8, 2, 0.4, 45, 0.05, "Clothing Brand Jeans Lifespan")
# Out:
# Z-Test: -3.354101966249684
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 22
Z_test(280, 300, 50, 25, 0.05, "Bakery Cupcakes Sold Per Day")
# Out:
# Z-Test: -2.0
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 23
Z_test(140, 150, 20, 35, 0.01, "Gym Attendance on Weekends")
# Out:
# Z-Test: -2.958039891549808
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 24
Z_test(42, 45, 5, 60, 0.05, "City Annual Rainfall")
# Out:
# Z-Test: -4.6475800154489
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 25
Z_test(2.8, 3, 0.5, 100, 0.01, "Video Streaming Service Watch Time")
# Out:
# Z-Test: -4.0000000000000036
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 26
Z_test(495, 500, 8, 40, 0.05, "Cereal Box Weight")
# Out:
# Z-Test: -3.952847075210474
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 27
Z_test(1.2, 1, 0.3, 200, 0.01, "Manufacturer Defect Rate")
# Out:
# Z-Test: 9.428090415820632
# Critical Z-Value: 2.5758293035489004
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 28
Z_test(4.5, 5, 1.2, 60, 0.05, "Student Extracurricular Time")
# Out:
# Z-Test: -3.227486121839514
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: True
# There is sufficient evidence to reject the null hypothesis

# %%
# Question 29
Z_test(7.5, 8, 1.5, 30, 0.05, "Mutual Fund ROI")
# Out:
# Z-Test: -1.8257418583505538
# Critical Z-Value: 1.959963984540054
# Reject Null Hypothesis: False
# There is insufficient evidence to reject the null hypothesis

# %%
# Given data
sample_mean = 33
population_mean = 30
population_std = 5
sample_size = 75
alpha = 0.01

# Hypotheses
# Null Hypothesis (H0): The average waiting time is 30 minutes (mu = 30)
# Alternative Hypothesis (Ha): The average waiting time is not 30 minutes (mu ≠ 30)

Z_test(33, 30, 5, 75, 0.01, "Theme Park Waiting Time")

# %%
# Given Data 
sample_mean = 1150
population_mean = 1200
population_std = 100
sample_size = 90
alpha = 0.05

# Hypotheses
# Null Hypothesis (H0): The average lifespan of a bulb is 1200 hours (mu = 1200)
# Alternative Hypothesis (Ha): The average lifespan of a bulb is not 1200 hours (mu ≠ 1200)

Z_test(1150, 1200, 100, 90, 0.05, "Light Bulb Lifespan")

# %%
# Question 32: Laptop Battery Life
sample_mean = 9.5
population_mean = 10
population_std = 1
sample_size = 60
alpha = 0.05

# Hypotheses
# Null Hypothesis (H0): The average battery life is 10 hours (mu = 10)
# Alternative Hypothesis (Ha): The average battery life is not 10 hours (mu ≠ 10)
Z_test(9.5, 10, 1, 60, 0.05, "Laptop Battery Life")

# %%
# Question 33
Z_test(16, 15, 3, 50, 0.01, "Restaurant Meal Preparation Time")

# %%
# Question 34
Z_test(28, 30, 4, 20, 0.05, "Software Data Processing Time Reduction")

# %%
# Question 35
Z_test(4.5, 5, 1, 25, 0.05, "Diet Plan Weight Loss")

# %%
# Question 36
Z_test(195, 200, 15, 45, 0.05, "Bank Customer Service Per Day")

# %%
# Question 37
Z_test(88, 90, 5, 50, 0.01, "Water Filter Impurity Reduction")

# %%
# Question 38
Z_test(2450, 2500, 150, 30, 0.05, "Vacation Package Cost")

# %%
# Question 39
Z_test(78, 80, 4, 100, 0.01, "Medication Success Rate")

# %%
# Question 40
Z_test(4.8, 5, 0.7, 70, 0.05, "Car Rental Period")

# %%
# Question 41
Z_test(1.9, 2, 0.3, 150, 0.05, "Music Streaming Listening Time")

# %%
# Question 42
Z_test(73, 75, 5, 40, 0.05, "University Exam Average Score")

# %%
# Question 43
Z_test(1.3, 1, 0.4, 25, 0.01, "Watch Accuracy")

# %%
# Question 44
Z_test(980, 1000, 20, 60, 0.05, "Microwave Power Usage")

# %%
# Question 45
Z_test(53500, 55000, 4000, 80, 0.05, "Graduate Starting Salary")

# %%
# Question 46
Z_test(78, 80, 5, 30, 0.05, "Energy Drink Caffeine Content")

# %%
# Question 47
Z_test(3.2, 3, 0.5, 100, 0.01, "Postal Delivery Time")

# %%
# Question 48
Z_test(4.7, 5, 0.8, 55, 0.05, "Gaming Console Lifespan")

# %%
# Question 49
Z_test(2.2, 2, 0.6, 40, 0.05, "Healthcare Recovery Time")

# %%
# Question 50
Z_test(42, 45, 7, 120, 0.05, "Customer Shopping Time")
